# %%
z,y,x = (201, 704, 600) #px
[201*0.2,0.097*704,600*0.097] #µm
# Out:
# [40.2, 68.288, 58.2]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

from numpy import genfromtxt


import pandas as pd

from mpl_toolkits import mplot3d
#%matplotlib notebook

import math

#import cv2
import pims
from PIL import Image

import skimage

import json

#own modules / functions
import sys

pythonPackagePath = "/Users/johannesschoeneberg/git/pyLattice/src/python/"
sys.path.append(pythonPackagePath+"/modules")
import TiffProcessing as tiffproc
import InputProcessing as inproc
sys.path.append(pythonPackagePath+"/classes")
import Track

# %% [markdown]
# # input data

# %%
#inputParameters = pd.read_csv(pythonPackagePath+'../../input/_inputParameters.csv',names=['key','value'])
inputParameters = pd.read_csv(pythonPackagePath+'../../input/big_data/_inputParameters.csv',names=['key','value'])
#inputParameters = pd.read_csv(pythonPackagePath+'../../input/big_data_cutoff7000_bleachCorrected/_inputParameters.csv',names=['key','value'])
#inputParameters = pd.read_csv(pythonPackagePath+'../../input/big_data_DMSO_cutoff7000_bleachCorrected/_inputParameters.csv',names=['key','value'])
#inputParameters = pd.read_csv(pythonPackagePath+'../../input/big_data_JASP_cutoff7000_bleachCorrected/_inputParameters.csv',names=['key','value'])
#inputParameters = pd.read_csv(pythonPackagePath+'../../input/big_data_LY_cutoff7000_bleachCorrected/_inputParameters.csv',names=['key','value'])

inputDataFolder = inproc.getInputParameter(inputParameters,"inputDataFolder")
outputDataFolder = inproc.getInputParameter(inputParameters,"outputDataFolder")
print(inputDataFolder)
print(outputDataFolder)
inputDataFolder = inputDataFolder.replace("6big","Samsung_T3b")#'/Volumes/Samsung_T3b/science/daphne_data_processing/2016-04-28Daphne__Sample7_CD_LY_10ulMG__Position2_O1_bleachCorr/output/'
outputDataFolder = outputDataFolder.replace("6big","Samsung_T3b")#'/Volumes/Samsung_T3b/science/daphne_data_processing/2016-04-28Daphne__Sample7_CD_LY_10ulMG__Position2_O1_bleachCorr/output/'
print(inputDataFolder)
print(outputDataFolder)

trackingCsvFilename = inproc.getInputParameter(inputParameters,"trackingCsvFilename")
trackingCsvFilenameProcessed = inproc.getInputParameter(inputParameters,"trackingCsvFilenameProcessed")

slave_outputDataFolder  = inproc.getInputParameter(inputParameters,"slave_outputDataFolder")
master_outputDataFolder  = inproc.getInputParameter(inputParameters,"master_outputDataFolder")

slave_uniqueFilenameString = inproc.getInputParameter(inputParameters,"slave_uniqueFilenameString")
master_uniqueFilenameString = inproc.getInputParameter(inputParameters,"master_uniqueFilenameString")


slave_trackingProcessedBildFilename = inproc.getInputParameter(inputParameters,"slave_trackingProcessedBildFilename")
master_trackingProcessedBildFilename = inproc.getInputParameter(inputParameters,"master_trackingProcessedBildFilename")



framerate_msec = float(inproc.getInputParameter(inputParameters,"framerate_msec"))
movieLength = int(inproc.getInputParameter(inputParameters,"movieLength"))


print(framerate_msec)
# Out:
# /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output
# /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output
# 5689.0

# %%
slave_filesOfInterest = inproc.getFilenamesOfInputTiffFiles(inputDataFolder,slave_uniqueFilenameString)
master_filesOfInterest = inproc.getFilenamesOfInputTiffFiles(inputDataFolder,master_uniqueFilenameString)
# Out:
# --- folder searched in: /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon
# --- example of files found: S3P5_488_150mw_560_300mw_Objdz150nm_ch0_CAM1_stack0000_488nm_0000000msec_0090116101msecAbs_000x_000y_003z_0000t_decon.tif
# --- number of files found: 70
# --- folder searched in: /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon
# --- example of files found: S3P5_488_150mw_560_300mw_Objdz150nm_ch1_CAM1_stack0000_560nm_0000000msec_0090116101msecAbs_000x_000y_003z_0000t_decon.tif
# --- number of files found: 70

# %%
# read the image from where the detections come from
frameId = 0

path = inputDataFolder+'/'+master_filesOfInterest[frameId]
print(path)
latticeMovieFrame = skimage.external.tifffile.imread(path)
latticeMovieFrame_shape = latticeMovieFrame.shape
print(latticeMovieFrame_shape)

tiffproc.maxIntensityProjection(latticeMovieFrame)
# Out:
# /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon/S3P5_488_150mw_560_300mw_Objdz150nm_ch1_CAM1_stack0000_560nm_0000000msec_0090116101msecAbs_000x_000y_003z_0000t_decon.tif
# (201, 704, 600)

# %%
# read the raw csv data for further processing

path = outputDataFolder+'/'+trackingCsvFilenameProcessed
print(path)
print(path)

data = pd.read_csv(path,header=0)
data.columns = ["trackId","tracklength","time[s]","frameId","lifetime","catIdx","m_x",'m_y',"m_z","m_A","m_c","m_pval_Ar","s_x",'s_y',"s_z","s_A","s_c","s_pval_Ar"]
trackIds = data.drop_duplicates(subset='trackId')['trackId'].values

data[0:5]
# Out:
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/trackedFeaturesProcessed.csv
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/trackedFeaturesProcessed.csv
#    trackId  tracklength        time[s] frameId  lifetime  catIdx  \
# 0        1           70              0       1    398.23       4
# 1        1           70   5.689000e+00       2    398.23       4
# 2        1           70   1.137800e+01       3    398.23       4
# 3        1           70   1.706700e+01       4    398.23       4
# 4        1           70   2.275600e+01       5    398.23       4
#
#              m_x            m_y            m_z            m_A            m_c  \
# 0   2.470622e+02   3.589416e+02   1.549039e+02   2.852619e+04   8.000496e+03
# 1   2.456148e+02   3.597828e+02   1.550418e+02   2.568300e+04   7.529965e+03
# 2   2.461329e+02   3.596650e+02   1.552289e+02   2.243185e+04   7.161439e+03
# 3   2.464530e+02   3.601393e+02   1.541899e+02   2.305632e+04   7.131548e+03
# 4   2.450720e+02   3.601834e+02   1.542996e+02   2.097679e+04   6.756136e+03
#
#   m_pval_Ar             s_x            s_y            s_z            s_A  \
# 0         0    2.467932e+02   3.583062e+02   1.549039e+02   2.463543e+04
# 1         0    2.478346e+02   3.586792e+02   1.550418e+02   3.039361e+04
# 2         0    2.481213e+02   3.588762e+02   1.552289e+02   2.262764e+04
# 3         0    2.480255e+02   3.576223e+02   1.541899e+02   1.986063e+04
# 4         0    2.437382e+02   3.597427e+02   1.542996e+02   1.916658e+04
#
#              s_c       s_pval_Ar
# 0   2.298148e+04   4.004483e-248
# 1   2.187127e+04   9.081350e-301
# 2   2.301794e+04   2.082318e-241
# 3   2.412181e+04   6.424817e-223
# 4   2.210576e+04   2.288247e-261

# %% [markdown]
# # select subset

# %%
# select a subset of the tracks, e.g. for displaying only long tracks

#%----------------------------------------------------------------------------
#    % I. Assign category to each track
#    %----------------------------------------------------------------------------
#    % Categories:
#    % Ia)  Single tracks with valid gaps
#    % Ib)  Single tracks with invalid gaps
#    % Ic)  Single tracks cut at beginning or end
#    % Id)  Single tracks, persistent
#    % IIa) Compound tracks with valid gaps
#    % IIb) Compound tracks with invalid gaps
#    % IIc) Compound tracks cut at beginning or end
#    % IId) Compound tracks, persistent
#    
#    % The categories correspond to index 1-8, in the above order

allTrackIdsLrgrThanFour = (data[data['tracklength'] >= 4]).drop_duplicates(subset='trackId')['trackId'].values
allTrackIds = np.unique(data['trackId'].values)
cat_Ia_Tracks = np.unique(data[data['catIdx'] == 1]['trackId'])
cat_Ia_Tracks_long = np.unique(data[((data['catIdx'] == 1) & (data['tracklength'] > 4))]['trackId'])
cat_Ib_Tracks = np.unique(data[data['catIdx'] == 2]['trackId'])
cat_Ic_Tracks = np.unique(data[data['catIdx'] == 3]['trackId'])
cat_Ic_Tracks_long = np.unique(data[((data['catIdx'] == 3) & (data['tracklength'] > 4))]['trackId'])
cat_Id_Tracks = np.unique(data[data['catIdx'] == 4]['trackId'])
cat_IIa_Tracks = np.unique(data[data['catIdx'] == 5]['trackId'])
cat_IIb_Tracks = np.unique(data[data['catIdx'] == 6]['trackId'])
cat_IIc_Tracks = np.unique(data[data['catIdx'] == 7]['trackId'])
cat_IId_Tracks = np.unique(data[data['catIdx'] == 8]['trackId'])


print('len(allTrackIdsLrgrThanFour)/len(allTrackIds)')
print(str(len(allTrackIdsLrgrThanFour))+'/'+str(len(allTrackIds)))
print()
print(allTrackIdsLrgrThanFour)
print('/')
print(allTrackIds)
print()
# Out:
# len(allTrackIdsLrgrThanFour)/len(allTrackIds)
# 1471/3274
#
# [   1    2    3 ..., 1469 1470 1471]
# /
# [   1    2    3 ..., 3272 3273 3274]

# %% [markdown]
# # write .bild file directly from the csv file

# %%
#plot them all
import math


def writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor='white'):

    
    file = open(path,'w') 
    
    file.write(".transparency 0.5\n")
    file.write(".color "+drawColor+"\n")
    
    nanLineCounter = 0
    lineCounter = 0
    trackCounter = 0
    for trackID in trackIdListToPlot:
        trackCounter = trackCounter +1
        line = ".comment trackID"+str(trackID)+"\n"
        file.write(line)
        
        
        track = data[data['trackId'] == trackID]
        tracklength = track['tracklength'].iloc[0]
        
        for i in range(1,tracklength):
            tzero = track.iloc[i-1]
            tone = track.iloc[i]
            
    
            # Data for a three-dimensional line
            x0 = float(tzero['m_x'])
            y0 = float(tzero['m_y'])
            z0 = np.abs(float(tzero['m_z']) - latticeMovieFrame_shape[2])
            A0 = float(tzero['m_A'])
            
            x1 = float(tone['m_x'])
            y1 = float(tone['m_y'])
            z1 = np.abs(float(tone['m_z'])- latticeMovieFrame_shape[2])
            A1 = float(tone['m_A'])
            
            if(math.isnan(x0) or math.isnan(y0) or math.isnan(z0) or math.isnan(x1) or math.isnan(y1) or math.isnan(z1)):
                line = ".arrow "+str(x0)+" "+str(y0)+" "+str(z0)+" "+str(x1)+" "+str(y1)+" "+str(z1)+"\n" #" "+str(radius)+"\n"        
                # print(line)
                nanLineCounter = nanLineCounter +1
                continue
            
            
            #.arrow x1 y1 z1 x2 y2 z2 [r1 [r2 [rho]]] 
            
            line = ".arrow "+str(x0)+" "+str(y0)+" "+str(z0)+" "+str(x1)+" "+str(y1)+" "+str(z1)+"\n" #" "+str(radius)+"\n"        
            lineCounter = lineCounter + 1
            file.write(line)
            
    print('# tracks: '+str(trackCounter))
    print('# lines written: '+str(lineCounter))
    print('# nan lines encountered and discarded: '+str(nanLineCounter))
    print(path)
    file.close()

# %%
# plot all tracks

trackData = data
trackIdListToPlot = np.unique(data['trackId'].values)
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/'+master_trackingProcessedBildFilename
drawColor = 'white'

writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)
# Out:
# # tracks: 3274
# # lines written: 13810
# # nan lines encountered and discarded: 86
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/tracksProcessed.bild

# %% [markdown]
# # write individual .bild files, through the track class

# %%
#decide for the color map
#https://matplotlib.org/examples/color/colormaps_reference.html
import matplotlib
cmap = matplotlib.cm.get_cmap('jet')
rgba = cmap(0.5)
print(rgba)
# Out:
# (0.49019607843137247, 1.0, 0.47754585705249841, 1.0)

# %%
# create Track objects for every track

import timeit


trackIdListInvestigated = cat_Ia_Tracks_long

start_time = timeit.default_timer()

tracks = []
cm0 = []
len0 = []
Amean0 = []
maxDist0 = []



for i in range(0,len(trackIdListInvestigated)):
    if(i %1000 == 0):
        print(str(i)+"/"+str(len(trackIdListInvestigated)))
    trackData = data[data['trackId'] == trackIdListInvestigated[i]]
    #a = Track.Track(trackData,latticeMovieFrame_shape)
    a = Track.Track(trackData)
    tracks.append(a)
    cm0.append(a.m_cm)
    len0.append(a.len)
    Amean0.append(a.m_Amean)
    maxDist0.append(a.m_maxDist)
    
elapsed = timeit.default_timer() - start_time
print('time elapse: '+str(np.round(elapsed,decimals=2))+'s')
# Out:
# 0/621
# time elapse: 1.2s

# %%
# go through all the Tracks in the list and write a bild file
latticeMovieFrame_shape = (201, 704, 600)
print(latticeMovieFrame_shape)
#latticeMovieFrame_shape = (0,0,0)

maxLength = 40.
for track in tracks:
    numberOfZeros = int(np.ceil(np.log10(movieLength+1)))
    output_filename = 'track_'+str(track.id).zfill(numberOfZeros)+'.bild'
    path = outputDataFolder+'/'+output_filename
    rgbcolor = np.around(cmap(float(track.len)/maxLength)[0:3],decimals=2)
    print(rgbcolor)
    print(path)
    
#    track.writeBILD(path,latticeMovieFrame_shape,color='orange')


    track.writeBILD(path,latticeMovieFrame_shape,color=rgbcolor,radius=0.25,center=[0,0,-300])
# Out:
# (201, 704, 600)
# [ 1.    0.22  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_31.bild
# [ 1.    0.41  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_34.bild
# [ 1.    0.58  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_39.bild
# [ 1.    0.58  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_40.bild
# [ 0.97  0.96  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_49.bild
# [ 0.97  0.96  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_50.bild
# [ 0.97  0.96  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_51.bild
# [ 0.97  0.96  0.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_52.bild
# [ 0.81  1.    0.16]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_61.bild
# [ 0.81  1.    0.16]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_62.bild
# [ 0.73  1.    0.24]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_68.bild
# [ 0.73  1.    0.24]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_69.bild
# [ 0.64  1.    0.33]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_75.bild
# [ 0.64  1.    0.33]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_76.bild
# [ 0.64  1.    0.33]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_77.bild
# [ 0.57  1.    0.4 ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_84.bild
# [ 0.49  1.    0.48]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_88.bild
# [ 0.49  1.    0.48]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_89.bild
# [ 0.49  1.    0.48]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_90.bild
# [ 0.49  1.    0.48]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_91.bild
# [ 0.4   1.    0.57]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_95.bild
# [ 0.4   1.    0.57]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_96.bild
# [ 0.33  1.    0.64]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_106.bild
# [ 0.33  1.    0.64]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_107.bild
# [ 0.33  1.    0.64]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_108.bild
# [ 0.33  1.    0.64]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_110.bild
# [ 0.33  1.    0.64]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_111.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_122.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_123.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_124.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_125.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_126.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_127.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_128.bild
# [ 0.24  1.    0.73]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_129.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_139.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_140.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_142.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_143.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_144.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_145.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_146.bild
# [ 0.16  1.    0.81]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_147.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_164.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_165.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_166.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_167.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_168.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_169.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_170.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_171.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_172.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_173.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_174.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_175.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_176.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_177.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_178.bild
# [ 0.09  1.    0.88]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_179.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_193.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_194.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_195.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_196.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_198.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_199.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_200.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_201.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_202.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_203.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_204.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_205.bild
# [ 0.    0.9   0.97]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_206.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_222.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_223.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_224.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_225.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_226.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_227.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_228.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_229.bild
# [ 0.   0.8  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_230.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_251.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_252.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_253.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_254.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_255.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_256.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_257.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_258.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_259.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_260.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_261.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_262.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_263.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_264.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_265.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_266.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_267.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_268.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_269.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_270.bild
# [ 0.    0.69  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_271.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_290.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_291.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_292.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_293.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_294.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_295.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_296.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_297.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_298.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_299.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_300.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_301.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_302.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_303.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_304.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_305.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_306.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_307.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_308.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_309.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_310.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_311.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_312.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_313.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_314.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_315.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_316.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_317.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_318.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_319.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_320.bild
# [ 0.   0.6  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_321.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_344.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_345.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_346.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_347.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_348.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_349.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_350.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_351.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_352.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_353.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_354.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_355.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_356.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_357.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_358.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_359.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_360.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_361.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_362.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_363.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_364.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_365.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_366.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_367.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_368.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_369.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_370.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_371.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_372.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_373.bild
# [ 0.   0.5  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_374.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_406.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_407.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_408.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_409.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_410.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_411.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_412.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_413.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_414.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_415.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_416.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_418.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_419.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_420.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_421.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_422.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_423.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_424.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_425.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_426.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_427.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_428.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_429.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_430.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_431.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_432.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_433.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_434.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_435.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_436.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_437.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_438.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_439.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_440.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_441.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_442.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_443.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_444.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_445.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_446.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_447.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_448.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_449.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_450.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_451.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_452.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_453.bild
# [ 0.    0.39  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_454.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_487.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_488.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_489.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_490.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_491.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_492.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_493.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_494.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_495.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_496.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_497.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_498.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_499.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_500.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_501.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_502.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_503.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_504.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_505.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_506.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_507.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_508.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_509.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_510.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_511.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_512.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_513.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_514.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_515.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_516.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_517.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_518.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_519.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_520.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_521.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_522.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_523.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_524.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_525.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_526.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_527.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_528.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_529.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_530.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_531.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_532.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_533.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_534.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_535.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_536.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_537.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_538.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_539.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_540.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_541.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_542.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_543.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_544.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_545.bild
# [ 0.   0.3  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_546.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_605.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_606.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_607.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_608.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_609.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_610.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_611.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_612.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_613.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_614.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_615.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_616.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_617.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_619.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_620.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_621.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_622.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_623.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_624.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_625.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_626.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_627.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_628.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_629.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_630.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_631.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_632.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_633.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_634.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_635.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_636.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_637.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_638.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_639.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_641.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_642.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_643.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_644.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_645.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_646.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_647.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_648.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_649.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_650.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_651.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_652.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_653.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_654.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_655.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_656.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_657.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_658.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_659.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_660.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_661.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_662.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_663.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_664.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_665.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_666.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_667.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_668.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_669.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_670.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_671.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_672.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_673.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_674.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_675.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_676.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_677.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_678.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_679.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_680.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_681.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_682.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_683.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_684.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_685.bild
# [ 0.    0.19  1.  ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_686.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_746.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_747.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_748.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_749.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_750.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_751.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_752.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_753.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_754.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_755.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_756.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_757.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_758.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_759.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_760.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_761.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_762.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_763.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_764.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_765.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_766.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_767.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_768.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_769.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_770.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_771.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_772.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_773.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_774.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_775.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_776.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_777.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_778.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_779.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_780.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_781.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_782.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_783.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_784.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_785.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_786.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_787.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_788.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_789.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_791.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_792.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_793.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_794.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_795.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_796.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_797.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_798.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_799.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_800.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_801.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_802.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_803.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_804.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_805.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_806.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_807.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_808.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_809.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_810.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_811.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_812.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_813.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_814.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_815.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_816.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_817.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_818.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_819.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_820.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_821.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_822.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_823.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_824.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_825.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_826.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_827.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_828.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_829.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_830.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_831.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_832.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_833.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_834.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_835.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_836.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_837.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_838.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_839.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_840.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_841.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_842.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_843.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_844.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_845.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_846.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_847.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_848.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_849.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_850.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_851.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_852.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_853.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_854.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_855.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_856.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_857.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_858.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_859.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_860.bild
# [ 0.   0.1  1. ]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_861.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_937.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_938.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_939.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_940.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_941.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_942.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_943.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_944.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_945.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_946.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_947.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_948.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_949.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_950.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_951.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_952.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_953.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_954.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_955.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_956.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_957.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_958.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_959.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_960.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_961.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_962.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_963.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_964.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_965.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_966.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_967.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_968.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_969.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_970.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_971.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_972.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_973.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_974.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_975.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_976.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_977.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_978.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_979.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_980.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_981.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_982.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_983.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_984.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_985.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_986.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_987.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_988.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_989.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_990.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_991.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_992.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_993.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_994.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_995.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_996.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_997.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_998.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_999.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1000.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1001.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1002.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1003.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1004.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1005.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1006.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1007.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1008.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1009.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1010.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1011.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1012.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1013.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1014.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1015.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1016.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1017.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1018.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1019.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1020.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1021.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1022.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1023.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1024.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1025.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1026.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1027.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1028.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1029.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1030.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1031.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1032.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1033.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1034.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1035.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1036.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1037.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1038.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1039.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1040.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1041.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1042.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1043.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1044.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1045.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1046.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1047.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1048.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1049.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1050.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1051.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1052.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1053.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1054.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1055.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1056.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1057.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1058.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1059.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1060.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1061.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1062.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1063.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1064.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1065.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1066.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1067.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1068.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1069.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1070.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1071.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1072.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1073.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1074.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1075.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1076.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1077.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1078.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1079.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1080.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1081.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1082.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1083.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1084.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1085.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1086.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1087.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1088.bild
# [ 0.  0.  1.]
# /Users/johannesschoeneberg/git/pyLattice/input/big_data/output/track_1089.bild

# %%
#plot them all

#%----------------------------------------------------------------------------
#    % I. Assign category to each track
#    %----------------------------------------------------------------------------
#    % Categories:
#    % Ia)  Single tracks with valid gaps
#    % Ib)  Single tracks with invalid gaps
#    % Ic)  Single tracks cut at beginning or end
#    % Id)  Single tracks, persistent
#    % IIa) Compound tracks with valid gaps
#    % IIb) Compound tracks with invalid gaps
#    % IIc) Compound tracks cut at beginning or end
#    % IId) Compound tracks, persistent
#    
#    % The categories correspond to index 1-8, in the above order



#data = longtracks
data = data

allTracks = np.unique(data['trackId'].values)
print('# all tracks '+ str(len(allTracks)))
cat_Ia_Tracks = np.unique(data[data['catIdx'] == 1]['trackId'])
cat_Ib_Tracks = np.unique(data[data['catIdx'] == 2]['trackId'])
cat_Ic_Tracks = np.unique(data[data['catIdx'] == 3]['trackId'])
cat_Id_Tracks = np.unique(data[data['catIdx'] == 4]['trackId'])
cat_IIa_Tracks = np.unique(data[data['catIdx'] == 5]['trackId'])
cat_IIb_Tracks = np.unique(data[data['catIdx'] == 6]['trackId'])
cat_IIc_Tracks = np.unique(data[data['catIdx'] == 7]['trackId'])
cat_IId_Tracks = np.unique(data[data['catIdx'] == 8]['trackId'])



trackData = data
trackIdListToPlot = cat_Ia_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_Ia_Tracks.bild'
drawColor = 'green'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

trackData = data
trackIdListToPlot = cat_Ib_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_Ib_Tracks.bild'
drawColor = 'yellow'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

trackData = data
trackIdListToPlot = cat_Ic_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_Ic_Tracks.bild'
drawColor = 'sienna'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

trackData = data
trackIdListToPlot = cat_Id_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_Id_Tracks.bild'
drawColor = 'red'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

#-------

trackData = data
trackIdListToPlot = cat_IIa_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_IIa_Tracks.bild'
drawColor = 'cyan'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

trackData = data
trackIdListToPlot = cat_IIb_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_IIb_Tracks.bild'
drawColor = 'blue'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

trackData = data
trackIdListToPlot = cat_IIc_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_IIc_Tracks.bild'
drawColor = 'purple'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)

trackData = data
trackIdListToPlot = cat_IId_Tracks
latticeMovieFrame_shape = latticeMovieFrame_shape
path = outputDataFolder+'/cat_IId_Tracks.bild'
drawColor = 'grey'
writeAllTracksProcessed_bildFile(trackData,trackIdListToPlot,latticeMovieFrame_shape,path,drawColor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31863b7c2743> in <module>()
#      19
#      20 #data = longtracks
# ---> 21 data = data
#      22
#      23 allTracks = np.unique(data['trackId'].values)
#
# NameError: name 'data' is not defined
