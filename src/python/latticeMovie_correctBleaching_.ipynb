# %%
# I want to create a rectangular box around a center.
# that will allow me to display the detection and tracking success in ChimeraX over time in a movie. Nice!

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from numpy import genfromtxt


import pandas as pd

from mpl_toolkits import mplot3d
#%matplotlib notebook



#import cv2
import pims
from PIL import Image

import skimage

import json

import sys
sys.path.append("./modules")
import TiffProcessing as tiffproc
import InputProcessing as inproc
sys.path.append("./classes")
import Track

# %% [markdown]
# # cube as a mesh

# %%
def getCubeMeshIndexes(cubeSize = 5, center=[0,0,0]):
# this is 5 on each side of the center
#center=np.array([224.29615185,362.37867407,45.60376889])
    indexes = []
    limits = np.array([-cubeSize,+cubeSize])
    for i in range(limits[0]-2,limits[1]+2):
        for j in  range(limits[0]-2,limits[1]+2):
            for k in range(limits[0]-2,limits[1]+2):
                value = 0
                if i in (limits+center[0]) and j in (limits+center[1]) and ((k > (limits+center[2])[0]) and (k < (limits+center[2])[1])) :
    #                print(limits+centerOfImage[0]+coord[0])
    #                print(limits+centerOfImage[1]+coord[1])
                    indexes.append([i,j,k])
                if j in limits+center[1] and k in limits+center[2] and ((i > (limits+center[0])[0]) and (i < (limits+center[0])[1])) :
                    indexes.append([i,j,k])
                if k in limits+center[2] and i in limits+center[0] and ((j > (limits+center[1])[0]) and (j < (limits+center[1])[1])) :
                    indexes.append([i,j,k])
    return(indexes)

# %% [markdown]
# # helper functions for lattice image processing

# %%
def maxIntensityProjection(latticeMovieFrame):
    
    path = inputDataFolder+'/'+ch0_filesOfInterest[0]
    latticeMovieFrame = skimage.external.tifffile.imread(inputDataFolder+'/'+ch0_filesOfInterest[10])
    
    f, axarr = plt.subplots(1,3,dpi=300)
    
    axarr[0].imshow(np.max(latticeMovieFrame,axis=0))
    axarr[0].set_xlabel('x')
    axarr[0].set_ylabel('y')
    axarr[0].invert_yaxis()
    
    
    axarr[1].imshow(np.max(latticeMovieFrame,axis=1))
    axarr[1].set_xlabel('x')
    axarr[1].set_ylabel('z')
    axarr[1].invert_yaxis()
    
    
    
    axarr[2].imshow(np.max(latticeMovieFrame,axis=2))
    axarr[2].set_xlabel('y')
    axarr[2].set_ylabel('z')
    axarr[2].invert_yaxis()
    
    plt.tight_layout()
    
    plt.show()

# %%
from os import listdir
from os.path import isfile, join
import fnmatch

def getFilenamesOfInputTiffFiles(inputDataFolder,uniqueFilenameString):

    folder = inputDataFolder
    print('--- folder searched in: '+folder)
    
    filesOfInterest = []
    for file in listdir(inputDataFolder):
        if isfile(join(inputDataFolder, file)) and fnmatch.fnmatch(file, '*'+uniqueFilenameString+'*.tif'):
            filesOfInterest.append(file)
    filesOfInterest=np.sort(filesOfInterest)
    
    
    
    print('--- example of files found: '+filesOfInterest[0])
    print('--- number of files found: '+str(len(filesOfInterest)))
    
    return(filesOfInterest)

# %% [markdown]
# # helper functions for this

# %%
def getRidOfNegativeIndexes(indexesArray):
    newIndexes = []
    for index in indexesArray:
        if(np.min(index)>=0):
            newIndexes.append(index)
    return(np.array(newIndexes))

# %%
def getIndexesWhereAllArrayEntriesArePositive(indexesArray):
    newIndexes = []
    for i in range(0,len(indexesArray)):
        index=indexesArray[i]
        if(np.min(index)>=0):
            newIndexes.append(i)
    return(np.array(newIndexes))

# %% [markdown]
# # input

# %%
def getInputParameter(inputParametersPandas,key):
    #this locates the row, gets the result out of its array form and strips whitespaces away
    return (((inputParametersPandas.loc[inputParametersPandas['key'] == key]).values)[0,1]).strip()

# %%
inputParameters = pd.read_csv('../_inputParameters.csv',names=['key','value'])
inputParameters.style.set_properties(**{'text-align': 'left'})
#inputParameters
# Out:
# <style  type="text/css" >
#     #T_2ae3d418_3897_11e8_8863_784f438ca174row0_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row0_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row1_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row1_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row2_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row2_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row3_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row3_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row4_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row4_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row5_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row5_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row6_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row6_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row7_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row7_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row8_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row8_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row9_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row9_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row10_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row10_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row11_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row11_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row12_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row12_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row13_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row13_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row14_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row14_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row15_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row15_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row16_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row16_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row17_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row17_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row18_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row18_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row19_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row19_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row20_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row20_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row21_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row21_col1 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row22_col0 {
#             text-align:  left;
#         }    #T_2ae3d418_3897_11e8_8863_784f438ca174row22_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_2ae3d418_3897_11e8_8863_784f438ca174" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >key</th>
#         <th class="col_heading level0 col1" >value</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row0_col0" class="data row0 col0" >inputDataFolder</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row0_col1" class="data row0 col1" > /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row1_col0" class="data row1 col0" >outputDataFolder</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row1_col1" class="data row1 col1" > /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row2_col0" class="data row2 col0" >movieLength</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row2_col1" class="data row2 col1" > 70</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row3_col0" class="data row3 col0" >allowedMaxNumDetectionsPerFrame</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row3_col1" class="data row3 col1" > 3000</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row4_col0" class="data row4 col0" >framerate_msec</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row4_col1" class="data row4 col1" > 5689</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row5_col0" class="data row5 col0" >detectionFilename</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row5_col1" class="data row5 col1" > Detection3D.mat</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row6_col0" class="data row6 col0" >trackingFilename</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row6_col1" class="data row6 col1" > trackedFeatures.mat</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row7_col0" class="data row7 col0" >trackingCsvFilename</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row7_col1" class="data row7 col1" > trackedFeatures.csv</td>
#     </tr>    <tr>
#         <th id="T_2ae3d418_3897_11e8_8863_784f438ca174level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row8_col0" class="data row8 col0" >trackingFilenameProcessed</td>
#         <td id="T_2ae3d418_3897_11e8_8863_784f438ca174row8_col1" class="data row8 col1" > trackedFeaturesProcessed.mat</td>
#     </tr>    <tr>
#         <th

# %%
inputDataFolder = getInputParameter(inputParameters,"inputDataFolder")
outputDataFolder = getInputParameter(inputParameters,"outputDataFolder")
slave_outputDataFolder  = getInputParameter(inputParameters,"slave_outputDataFolder")
master_outputDataFolder  = getInputParameter(inputParameters,"master_outputDataFolder")
trackingCsvFilename = getInputParameter(inputParameters,"trackingCsvFilename")

slave_uniqueFilenameString = getInputParameter(inputParameters,"slave_uniqueFilenameString")
master_uniqueFilenameString = getInputParameter(inputParameters,"master_uniqueFilenameString")
#trackColor = getInputParameter(inputParameters,"trackColor")
#trackingBildFilename = getInputParameter(inputParameters,"trackingBildFilename")
#framerate_msec = float(getInputParameter(inputParameters,"framerate_msec"))
movieLength = int(getInputParameter(inputParameters,"movieLength"))
#print(trackColor)

# %%
    slave_filesOfInterest = getFilenamesOfInputTiffFiles(inputDataFolder,slave_uniqueFilenameString)
    master_filesOfInterest = getFilenamesOfInputTiffFiles(inputDataFolder,master_uniqueFilenameString)
# Out:
# --- folder searched in: /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/
# --- example of files found: cropped_488_pm50px_maxAmpl_0000.tif
# --- number of files found: 70
# --- folder searched in: /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/
# --- example of files found: cropped_560_pm50px_maxAmpl_0000.tif
# --- number of files found: 70

# %% [markdown]
# # Master

# %%
frameId = 0

# %%
# read the image from where the detections come from
frameId = 69

path = inputDataFolder+'/'+master_filesOfInterest[frameId]
print(path)
latticeMovieFrame = skimage.external.tifffile.imread(path)
latticeMovieFrame_shape = latticeMovieFrame.shape
print(latticeMovieFrame_shape)

tiffproc.maxIntensityProjection(latticeMovieFrame)
# Out:
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100//cropped_560_pm50px_maxAmpl_0069.tif
# (100, 100, 100)

# %%
# read the image from where the detections come from
frameId = 69

path = inputDataFolder+'/'+master_filesOfInterest[frameId]
print(path)
latticeMovieFrame = skimage.external.tifffile.imread(path)

plt.hist(latticeMovieFrame.flatten(),bins=100);
plt.ylim(0,160000)
plt.xlim(0,35000)
plt.xlabel('intensity')
plt.ylabel('counts')
plt.title('frameID '+str(frameId))
# Out:
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100//cropped_560_pm50px_maxAmpl_0069.tif
# Text(0.5,1,'frameID 69')

# %%
# read the image from where the detections come from

m_frame_max = []
m_frame_mean = []
m_ratio = []
s_frame_max = []
s_frame_mean = []
s_ratio = []
for frameId in range(0,70):

    path = inputDataFolder+'/'+master_filesOfInterest[frameId]
    #print(path)
    latticeMovieFrame = skimage.external.tifffile.imread(path)
    
    m_frame_max.append(np.max(latticeMovieFrame))
    m_frame_mean.append(np.mean(latticeMovieFrame))
    m_ratio.append(np.mean(latticeMovieFrame)/np.mean(skimage.external.tifffile.imread(inputDataFolder+'/'+master_filesOfInterest[0])))
    
    path = inputDataFolder+'/'+slave_filesOfInterest[frameId]
    #print(path)
    latticeMovieFrame = skimage.external.tifffile.imread(path)
    
    s_frame_max.append(np.max(latticeMovieFrame))
    s_frame_mean.append(np.mean(latticeMovieFrame))
    s_ratio.append(np.mean(latticeMovieFrame)/np.mean(skimage.external.tifffile.imread(inputDataFolder+'/'+slave_filesOfInterest[0])))

# %%
plt.plot(m_frame_max,c='magenta')
plt.plot(s_frame_max,c='lime')
plt.show()
plt.plot(m_frame_mean,c='magenta')
plt.plot(s_frame_mean,c='lime')
plt.show()
#fig = plt.figure(dpi=300)
plt.plot(m_ratio,c='magenta')
plt.plot(s_ratio,c='lime')
plt.xlabel('frameID')
plt.ylabel('ratio')
# Out:
# Text(0,0.5,'ratio')

# %%
# ratio method

# %%
# read the image from where the detections come from

for frameId in range(0,70):

    
    # master files
    path = inputDataFolder+'/'+master_filesOfInterest[frameId]
    #print(path)
    latticeMovieFrame = skimage.external.tifffile.imread(path)
    

    data = latticeMovieFrame/m_ratio[frameId]
    metadata = dict(microscope='joh', shape=data.shape, dtype=data.dtype.str)
    metadata = json.dumps(metadata)
    
    output_filename = master_filesOfInterest[frameId]+'_ratioCorrected.tif'
    path = outputDataFolder+'/'+output_filename
    print(path)
    
    skimage.external.tifffile.imsave(path, data, description=metadata)
    
    
    
    # slave files
    path = inputDataFolder+'/'+slave_filesOfInterest[frameId]
    #print(path)
    latticeMovieFrame = skimage.external.tifffile.imread(path)
    

    data = latticeMovieFrame/s_ratio[frameId]
    metadata = dict(microscope='joh', shape=data.shape, dtype=data.dtype.str)
    metadata = json.dumps(metadata)
    
    output_filename = slave_filesOfInterest[frameId]+'_ratioCorrected.tif'
    path = outputDataFolder+'/'+output_filename
    print(path)
    
    skimage.external.tifffile.imsave(path, data, description=metadata)
# Out:
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0000.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0000.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0001.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0001.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0002.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0002.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0003.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0003.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0004.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0004.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0005.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0005.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0006.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0006.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0007.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0007.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0008.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0008.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0009.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0009.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0010.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0010.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0011.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0011.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0012.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0012.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0013.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0013.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0014.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0014.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0015.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0015.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0016.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0016.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0017.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0017.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0018.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0018.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0019.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0019.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0020.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0020.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0021.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0021.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0022.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0022.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0023.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0023.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0024.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0024.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0025.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0025.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0026.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0026.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0027.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0027.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0028.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0028.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0029.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0029.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0030.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0030.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0031.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0031.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0032.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0032.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0033.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0033.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0034.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0034.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0035.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0035.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0036.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0036.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0037.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0037.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0038.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0038.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0039.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0039.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0040.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0040.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0041.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0041.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0042.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0042.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0043.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0043.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0044.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0044.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0045.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0045.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0046.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0046.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0047.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0047.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0048.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0048.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0049.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0049.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0050.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0050.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0051.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0051.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0052.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0052.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0053.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0053.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0054.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0054.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0055.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0055.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0056.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0056.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0057.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0057.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0058.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0058.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0059.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0059.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0060.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0060.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0061.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0061.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0062.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0062.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0063.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0063.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0064.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0064.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0065.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0065.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0066.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0066.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0067.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0067.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0068.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0068.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_560_pm50px_maxAmpl_0069.tif_ratioCorrected.tif
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/cropped_488_pm50px_maxAmpl_0069.tif_ratioCorrected.tif

# %%
# model based method (exponential decay)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import scipy.optimize


def main():

    t = np.array(range(0,70))
    y = np.array(frame_mean)
    C0= 1500


    fig = plt.figure(dpi=300)
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # Non-linear Fit
    A, K, C = fit_exp_nonlinear(t, y)
    print(A,K,C)
    fit_y = model_func(t, A, K, C)
    plot(ax1, t, y, fit_y, (A, K, C))
    ax1.set_title('Non-linear Fit')
    ax1.set_ylim(1000,3000)

    # Linear Fit (Note that we have to provide the y-offset ("C") value!!
    A, K = fit_exp_linear(t, y, C0)
    fit_y = model_func(t, A, K, C0)
    plot(ax2, t, y, fit_y, (A, K, C0))
    ax2.set_title('Linear Fit')

    plt.show()

def model_func(t, A, K, C):
    return A * np.exp(K * t) + C

def fit_exp_linear(t, y, C=0):
    y = y - C
    y = np.log(y)
    K, A_log = np.polyfit(t, y, 1)
    A = np.exp(A_log)
    print('linear',K,A_log)
    return A, K

def fit_exp_nonlinear(t, y):
    opt_parms, parm_cov = sp.optimize.curve_fit(model_func, t, y, maxfev=10000,p0=(0 ,-0.3, 1500))
    A, K, C = opt_parms
    print('nonlinear',A,K,C)
    return A, K, C

def plot(ax, t, y, fit_y, fit_parms):
    A, K, C = fit_parms
    
    ax.plot(t, y, 'ro')
    ax.plot(t, fit_y, 'b-',
      label='Fitted Function:\n $y = %0.2f e^{%0.2f t} + %0.2f$' % (A, K, C))

    ax.legend(bbox_to_anchor=(1.05, 1.1), fancybox=True, shadow=True)

if __name__ == '__main__':
    main()
# Out:
# nonlinear 898.480943894 -0.0482470599473 1625.87499794
# 898.480943894 -0.0482470599473 1625.87499794
# linear -0.02871835899 6.78260486495

# %%
# read the detected coordinates
detectedPunctaPerFrameArray = []
for frameId in range(0,movieLength):

    # matlab format rule: fmt = ['%.' num2str(ceil(log10(movieLength+1))) 'd'];
    numberOfZeros = int(np.ceil(np.log10(movieLength+1)))
    input_filename = 'puncta_'+str(frameId+1).zfill(numberOfZeros)+'.csv'
    output_filename = 'puncta_'+str(frameId+1).zfill(numberOfZeros)+'.tiff'
    
    path = outputDataFolder+'/'+master_outputDataFolder+'/'+input_filename
    print(path)
    
    data = pd.read_csv(path,header=0)
    data.columns = ["x","y","z","A"]
    
    
    #### WARNING ####
    
    # this is really weird!
    # for some reason, I have to invert all the coordinates to display them again...
    
    allDetectedPunctaInFrame = data[['z','y','x']].values.astype(int)-np.array([1,1,1])
    print('#puncta read in frameId '+str(frameId)+':',len(allDetectedPunctaInFrame))
    detectedPunctaPerFrameArray.append(allDetectedPunctaInFrame)
# Out:
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_01.csv
# #puncta read in frameId 0: 140
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_02.csv
# #puncta read in frameId 1: 151
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_03.csv
# #puncta read in frameId 2: 144
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_04.csv
# #puncta read in frameId 3: 152
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_05.csv
# #puncta read in frameId 4: 153
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_06.csv
# #puncta read in frameId 5: 161
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_07.csv
# #puncta read in frameId 6: 168
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_08.csv
# #puncta read in frameId 7: 191
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_09.csv
# #puncta read in frameId 8: 204
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_10.csv
# #puncta read in frameId 9: 220

# %% [markdown]
# # write the cubes

# %%
# this works. Nice!


margin = 0

imageSizeOriginal = latticeMovieFrame_shape
imageSize = np.array((imageSizeOriginal[0]+margin,imageSizeOriginal[1]+margin,imageSizeOriginal[2]+margin))


centerOfImage = np.array([imageSize[0]//2,imageSize[1]//2,imageSize[2]//2])-np.array([1,1,1])
centerOfImage = np.array([imageSize[0]//2,imageSize[1]//2,imageSize[2]//2])-np.array([1,1,1])

for frameId in range(0,movieLength):

    boxCenters = detectedPunctaPerFrameArray[frameId]
    
    image = np.zeros(imageSize)
    print(imageSize)
    
    meshIndexes = getCubeMeshIndexes()
    meshIndexesAdjustedArray = []
    counter = 0
    
    for boxCenter in boxCenters:
        
        
        if counter%100 == 0:
            print(counter)
            
            
     #   if(boxCenter[1]>imageSize[1]):
     #       boxCenter[1]=boxCenter[1]-imageSize[1]
     #       print(boxCenter)
    
    
        # I run into problems if the box Center leads to negative values -> prune them
        meshIndexesAdjusted = meshIndexes+boxCenter
        if np.min(meshIndexesAdjusted)<0:
            meshIndexesAdjusted = meshIndexesAdjusted[getIndexesWhereAllArrayEntriesArePositive(meshIndexesAdjusted)]
        meshIndexesAdjustedArray.append(meshIndexesAdjusted)
        
        
        # I run into problems if the box center leads to indexes that are larger than the image -> prune them
        boolArray = boxCenter+np.array([6,6,6]) >= imageSize
        if(True in boolArray):
            # these values are larger than the image size, subtract the image size first, get negative values
            tmp = imageSize-np.array([1,1,1]) - meshIndexesAdjusted
            # add the image size back after gotten rid of the negative ones
            idx=getIndexesWhereAllArrayEntriesArePositive(tmp)
            if(len(idx)==0):
                print('weird box center (not in image), excluded from display: ')
                print(boxCenter)
                print(imageSize)
                meshIndexesAdjusted = []
            else:
                meshIndexesAdjusted = meshIndexesAdjusted[idx]
                    
            
        
        
        for index in meshIndexesAdjusted:
            #print(index)
        #    print('index',index)
            image[index[0],index[1],index[2]]=10
        
        #print(image)
        
        
        counter = counter+1

    data = image.astype('uint16')
    metadata = dict(microscope='joh', shape=data.shape, dtype=data.dtype.str)
    metadata = json.dumps(metadata)
    print(metadata)
    
    output_filename = 'puncta_'+str(frameId+1).zfill(numberOfZeros)+'.tiff'
    path = outputDataFolder+'/'+master_outputDataFolder+'/'+output_filename
    print(path)
    
    skimage.external.tifffile.imsave(path, data, description=metadata)
# Out:
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_01.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_02.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_03.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_04.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_05.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_06.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_07.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_08.tiff
# [100 100 100]
# 0
# 100
# 200
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_09.tiff
# [100 100 100]
# 0
# 100
# 200
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_560/puncta_10.tiff

# %% [markdown]
# # Slave

# %%
# read the image from where the detections come from
frameId = 0

path = inputDataFolder+'/'+slave_filesOfInterest[frameId]
print(path)
latticeMovieFrame = skimage.external.tifffile.imread(path)
latticeMovieFrame_shape = latticeMovieFrame.shape
print(latticeMovieFrame_shape)

tiffproc.maxIntensityProjection(latticeMovieFrame)
# Out:
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100//cropped_488_pm50px_maxAmpl_0000.tif
# (100, 100, 100)

# %%
# read the detected coordinates
detectedPunctaPerFrameArray = []
for frameId in range(0,movieLength):

    # matlab format rule: fmt = ['%.' num2str(ceil(log10(movieLength+1))) 'd'];
    numberOfZeros = int(np.ceil(np.log10(movieLength+1)))
    input_filename = 'puncta_'+str(frameId+1).zfill(numberOfZeros)+'.csv'
    output_filename = 'puncta_'+str(frameId+1).zfill(numberOfZeros)+'.tiff'
    
    path = outputDataFolder+'/'+slave_outputDataFolder+'/'+input_filename
    print(path)
    
    data = pd.read_csv(path,header=0)
    data.columns = ["x","y","z","A"]
    
    
    #### WARNING ####
    
    # this is really weird!
    # for some reason, I have to invert all the coordinates to display them again...
    
    allDetectedPunctaInFrame = data[['z','y','x']].values.astype(int)-np.array([1,1,1])
    print('#puncta read in frameId '+str(frameId)+':',len(allDetectedPunctaInFrame))
    detectedPunctaPerFrameArray.append(allDetectedPunctaInFrame)
# Out:
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_01.csv
# #puncta read in frameId 0: 140
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_02.csv
# #puncta read in frameId 1: 151
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_03.csv
# #puncta read in frameId 2: 144
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_04.csv
# #puncta read in frameId 3: 152
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_05.csv
# #puncta read in frameId 4: 153
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_06.csv
# #puncta read in frameId 5: 161
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_07.csv
# #puncta read in frameId 6: 168
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_08.csv
# #puncta read in frameId 7: 191
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_09.csv
# #puncta read in frameId 8: 204
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_10.csv
# #puncta read in frameId 9: 220

# %%
# this works. Nice!


margin = 0

imageSizeOriginal = latticeMovieFrame_shape
imageSize = np.array((imageSizeOriginal[0]+margin,imageSizeOriginal[1]+margin,imageSizeOriginal[2]+margin))


centerOfImage = np.array([imageSize[0]//2,imageSize[1]//2,imageSize[2]//2])-np.array([1,1,1])
centerOfImage = np.array([imageSize[0]//2,imageSize[1]//2,imageSize[2]//2])-np.array([1,1,1])

for frameId in range(0,movieLength):

    boxCenters = detectedPunctaPerFrameArray[frameId]
    
    image = np.zeros(imageSize)
    print(imageSize)
    
    meshIndexes = getCubeMeshIndexes()
    meshIndexesAdjustedArray = []
    counter = 0
    
    for boxCenter in boxCenters:
        
        
        if counter%100 == 0:
            print(counter)
            
            
     #   if(boxCenter[1]>imageSize[1]):
     #       boxCenter[1]=boxCenter[1]-imageSize[1]
     #       print(boxCenter)
    
    
        # I run into problems if the box Center leads to negative values -> prune them
        meshIndexesAdjusted = meshIndexes+boxCenter
        if np.min(meshIndexesAdjusted)<0:
            meshIndexesAdjusted = meshIndexesAdjusted[getIndexesWhereAllArrayEntriesArePositive(meshIndexesAdjusted)]
        meshIndexesAdjustedArray.append(meshIndexesAdjusted)
        
        
        # I run into problems if the box center leads to indexes that are larger than the image -> prune them
        boolArray = boxCenter+np.array([6,6,6]) >= imageSize
        if(True in boolArray):
            # these values are larger than the image size, subtract the image size first, get negative values
            tmp = imageSize-np.array([1,1,1]) - meshIndexesAdjusted
            # add the image size back after gotten rid of the negative ones
            idx=getIndexesWhereAllArrayEntriesArePositive(tmp)
            if(len(idx)==0):
                print('weird box center (not in image), excluded from display: ')
                print(boxCenter)
                print(imageSize)
                meshIndexesAdjusted = []
            else:
                meshIndexesAdjusted = meshIndexesAdjusted[idx]
                    
            
        
        
        for index in meshIndexesAdjusted:
            #print(index)
        #    print('index',index)
            image[index[0],index[1],index[2]]=10
        
        #print(image)
        
        
        counter = counter+1

    data = image.astype('uint16')
    metadata = dict(microscope='joh', shape=data.shape, dtype=data.dtype.str)
    metadata = json.dumps(metadata)
    print(metadata)
    
    output_filename = 'puncta_'+str(frameId+1).zfill(numberOfZeros)+'.tiff'
    path = outputDataFolder+'/'+slave_outputDataFolder+'/'+output_filename
    print(path)
    
    skimage.external.tifffile.imsave(path, data, description=metadata)
# Out:
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_01.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_02.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_03.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_04.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_05.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_06.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_07.tiff
# [100 100 100]
# 0
# 100
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_08.tiff
# [100 100 100]
# 0
# 100
# 200
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_09.tiff
# [100 100 100]
# 0
# 100
# 200
# {"microscope": "joh", "shape": [100, 100, 100], "dtype": "<u2"}
# /Users/johannesschoeneberg/git/LatticeTrack/data/test_input/crop_100x100x100/output/output_488/puncta_10.tiff
