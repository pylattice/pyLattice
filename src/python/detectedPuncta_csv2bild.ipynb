# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from numpy import genfromtxt


import pandas as pd

from mpl_toolkits import mplot3d
#%matplotlib notebook

# %%
inputParameters = pd.read_csv('../_inputParameters.csv',names=['key','value'])
inputParameters.style.set_properties(**{'text-align': 'left'})
#inputParameters
# Out:
# <style  type="text/css" >
#     #T_f5e190e8_2895_11e8_a276_784f438ca174row0_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row0_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row1_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row1_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row2_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row2_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row3_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row3_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row4_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row4_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row5_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row5_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row6_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row6_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row7_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row7_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row8_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row8_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row9_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row9_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row10_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row10_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row11_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row11_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row12_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row12_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row13_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row13_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row14_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row14_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row15_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row15_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row16_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row16_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row17_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row17_col1 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row18_col0 {
#             text-align:  left;
#         }    #T_f5e190e8_2895_11e8_a276_784f438ca174row18_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_f5e190e8_2895_11e8_a276_784f438ca174" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >key</th>
#         <th class="col_heading level0 col1" >value</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row0_col0" class="data row0 col0" >inputDataFolder</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row0_col1" class="data row0 col1" > /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row1_col0" class="data row1 col0" >outputDataFolder</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row1_col1" class="data row1 col1" > /Users/johannesschoeneberg/Desktop/PostDoc/drubin_lab/organoids_lattice_data/data_/2016_04_25Daphne/Sample3_CD_10ulMG/Position5_Basal_apical_ObjScan/matlab_decon/output</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row2_col0" class="data row2 col0" >movieLength</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row2_col1" class="data row2 col1" > 70</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row3_col0" class="data row3 col0" >allowedMaxNumDetectionsPerFrame</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row3_col1" class="data row3 col1" > 3000</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row4_col0" class="data row4 col0" >framerate_msec</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row4_col1" class="data row4 col1" > 5689</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row5_col0" class="data row5 col0" >ch0_outputDataFolder</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row5_col1" class="data row5 col1" > output_488</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row6_col0" class="data row6 col0" >ch0_uniqueFilenameString</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row6_col1" class="data row6 col1" > 488nm_0</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row7_col0" class="data row7 col0" >ch0_detectionFilename</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row7_col1" class="data row7 col1" > Detection3D.mat</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row8_col0" class="data row8 col0" >ch0_trackingFilename</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row8_col1" class="data row8 col1" > trackedFeatures.mat</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row9_col0" class="data row9 col0" >ch0_trackingCsvFilename</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row9_col1" class="data row9 col1" > trackedFeatures.csv</td>
#     </tr>    <tr>
#         <th id="T_f5e190e8_2895_11e8_a276_784f438ca174level0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_f5e190e8_2895_11e8_a276_784f438ca174row10_col0" class="data row10 col0" >ch0_trackColor</td>
#         <td id="T_f5e190e8_2895_11e8_a276_784f43

# %%
def getInputParameter(inputParametersPandas,key):
    #this locates the row, gets the result out of its array form and strips whitespaces away
    return (((inputParametersPandas.loc[inputParametersPandas['key'] == key]).values)[0,1]).strip()

# %%
inputDataFolder = getInputParameter(inputParameters,"inputDataFolder")
outputDataFolder = getInputParameter(inputParameters,"outputDataFolder")
ch0_outputDataFolder  = getInputParameter(inputParameters,"ch0_outputDataFolder")
ch0_trackingCsvFilename = getInputParameter(inputParameters,"ch0_trackingCsvFilename")
ch1_outputDataFolder  = getInputParameter(inputParameters,"ch1_outputDataFolder")
ch1_trackingCsvFilename = getInputParameter(inputParameters,"ch1_trackingCsvFilename")

ch0_uniqueFilenameString = getInputParameter(inputParameters,"ch0_uniqueFilenameString")
ch1_uniqueFilenameString = getInputParameter(inputParameters,"ch1_uniqueFilenameString")
#trackColor = getInputParameter(inputParameters,"trackColor")
#trackingBildFilename = getInputParameter(inputParameters,"trackingBildFilename")
#framerate_msec = float(getInputParameter(inputParameters,"framerate_msec"))
movieLength = int(getInputParameter(inputParameters,"movieLength"))
#print(trackColor)

# %%
#http://www.cgl.ucsf.edu/pipermail/chimera-users/2010-November/005715.html
def pandasData2bildFile(data,filename='puncta.bild'):
    file = open(filename,'w') 
    radius = 1
    #.transparency value 
    file.write(".transparency 0.5\n")
    file.write(".color red\n")
    file.write(".dot 0 0 0\n")
    #Set the transparency of subsequently defined items. The value can range from 0.0 (not transparent) to 1.0 (completely transparent).
    for i in range(0,len(data)):
        dataLine = data.iloc[i].values
        line = ".sphere "+str(dataLine[0])+" "+str(dataLine[1])+" "+str(dataLine[2])+" "+str(radius)+"\n"
        file.write(line)
    file.close()

# %%
folder = outputDataFolder+'/'+ch1_outputDataFolder+'/'

data = pd.read_csv(folder+'puncta_1.csv',header=0)
data.columns = ["x","y","z","A"]
print(len(data))
data[0:5]
pandasData2bildFile(data)
# Out:
# 2811

# %%
for i in range(1,48):
    filename = 'puncta_'+str(i)+'.csv'
    data = pd.read_csv(filename,header=0)
    data.columns = ["x","y","z","A"]
    print(len(data))
    data[0:5]
    pandasData2bildFile(data,filename+".bild")
# Out:
# 32632
# 31908
# 30946
# 30618
# 30323
# 29975
# 29437
# 29398
# 29202
# 28284
# 28187
# 28019
# 27462
# 27282
# 27041
# 26601
# 26461
# 26076
# 25799
# 25642
# 25532
# 25239
# 24836
# 24587
# 24246
# 24123
# 23828
# 23649
# 23415
# 23101
# 22816
# 22809
# 22443
# 22395
# 21846
# 21647
# 21475
# 21210
# 21161
# 20895
# 20923
# 20688
# 20305
# 19937
# 19835
# 19392
# 19731
