# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

from numpy import genfromtxt


import pandas as pd

from mpl_toolkits import mplot3d
#%matplotlib notebook

import math

#import cv2
import pims
from PIL import Image

import skimage

import json

#own modules / functions
import sys

pythonPackagePath = "/Users/johannesschoeneberg/git/pyLattice/src/python/"
sys.path.append(pythonPackagePath+"/modules")
import TiffProcessing as tiffproc
import InputProcessing as inproc
sys.path.append(pythonPackagePath+"/classes")
import Track

# %%
#baso
#dmso 

cltr_dmso_api=[5485.4175475285265, 7418.1391838709587, 7816.2974626168252, 9027.9700990098991]
cltr_dmso_api_std=[8211.6475155032349, 8909.680581345996, 7182.0896090881461, 10929.566734981578]
dnm2_dmso_api=[9875.5041931558844, 17205.872153225824, 26601.338803738305, 34013.086475247532]
dnm2_dmso_api_std=[14677.952779938625, 21619.040620395328, 31428.825563840674, 25669.296287883481]



cltr_jasp_api=[3109.7874629629569, 3947.7900906976793, 5715.0118285714325, 7315.7042142857135]
cltr_jasp_api_std=[3094.2922792566342, 3607.1013694188014, 5023.9786759753533, 5478.8558311094048]
dnm2_jasp_api=[15610.010212962978, 22246.302116279079, 28032.814114285728, 35392.208535714293]
dnm2_jasp_api_std=[17767.214189179547, 24399.036455154041, 35737.215293406363, 24910.823545767413]




# data to plot

A = cltr_dmso_api
B = dnm2_dmso_api
C = cltr_jasp_api
D = dnm2_jasp_api
n_groups = len(A) 
    
# create plot
fig, ax = plt.subplots(dpi=300)
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8
 
rects1 = plt.bar(index-1.5*bar_width, A, bar_width,
                 alpha=opacity,
                 color='magenta',
                 label='Ctrl. Cltr')

rects2 = plt.bar(index -0.5*bar_width, B, bar_width,
                 alpha=opacity,
                 color='lime',
                 label='Ctrl. Dnm2')

rects1 = plt.bar(index+1.*bar_width, C, bar_width,
                 alpha=opacity,
                 color='darkmagenta',
                 label='JASP Cltr')

rects2 = plt.bar(index +2.*bar_width, D, bar_width,
                 alpha=opacity,
                 color='limegreen',
                 label='JASP Dnm2')



 
#plt.xlabel('Person')
plt.ylabel('intensity[AU]')
plt.title('baso')
plt.xticks(index + bar_width/3, ('0s-34s', '34s-68s', '68s-102s', '102s-136s', '136s-170s', '170s-398s'))

plt.legend()
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.ylim(0,85000)
plt.tight_layout()
plt.show()

# %%
# inter
# dmso

cltr_dmso_api=[5120.4672025316449, 7191.0441769230674, 8700.1910627177695, 7827.6621249999862]
cltr_dmso_api_std=[5641.1483812484985, 8740.1152718667272, 8501.941584717164, 6869.3743616990714]
dnm2_dmso_api=[7827.7308639240528, 13798.630095384622, 23157.526634146314, 30983.255769736825]
dnm2_dmso_api_std=[11924.39015397072, 17606.57775012506, 23069.335199541456, 27221.338551701312]

cltr_jasp_api=[4348.5402515151509, 5186.0922047556105, 6365.6304936170054, 8351.6062183908125]
cltr_jasp_api_std=[5335.9248327024679, 5798.4694300016845, 5092.7396184684721, 7646.2894810668595]
dnm2_jasp_api=[17108.441057272728, 24398.352575957717, 31902.130565957421, 36508.290839080444]
dnm2_jasp_api_std=[25018.045906836673, 33730.384952052373, 29466.394609932489, 31774.120360309102]




# data to plot

A = cltr_dmso_api
B = dnm2_dmso_api
C = cltr_jasp_api
D = dnm2_jasp_api
n_groups = len(A) 
    
# create plot
fig, ax = plt.subplots(dpi=300)
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8
 
rects1 = plt.bar(index-1.5*bar_width, A, bar_width,
                 alpha=opacity,
                 color='magenta',
                 label='Ctrl. Cltr')

rects2 = plt.bar(index -0.5*bar_width, B, bar_width,
                 alpha=opacity,
                 color='lime',
                 label='Ctrl. Dnm2')

rects1 = plt.bar(index+1.*bar_width, C, bar_width,
                 alpha=opacity,
                 color='darkmagenta',
                 label='JASP Cltr')

rects2 = plt.bar(index +2.*bar_width, D, bar_width,
                 alpha=opacity,
                 color='limegreen',
                 label='JASP Dnm2')



 
#plt.xlabel('Person')
plt.ylabel('intensity[AU]')
plt.title('inter')
plt.xticks(index + bar_width/3, ('0s-34s', '34s-68s', '68s-102s', '102s-136s', '136s-170s', '170s-398s'))

plt.legend()
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.ylim(0,85000)
plt.tight_layout()
plt.show()

# %%
# api

#api
cltr_dmso_api=[4046.7774291338574, 5283.5319244094389, 6923.8385281690189, 7355.0069225352072]
cltr_dmso_api_std=[4749.706795032047, 5843.67258133415, 6459.4005840219279, 5863.8624419649195]
dnm2_dmso_api=[12566.606397637788, 18200.568903937012, 25313.190602112678, 29798.792739436612]
dnm2_dmso_api_std=[17488.888043848572, 18310.293079585568, 19190.297491839865, 21339.90225406328]

cltr_jasp_api=[3535.6366715686181, 4610.0755648854938, 5805.8084013157895, 6853.0148181818222]
cltr_jasp_api_std=[3224.5043093793088, 3929.5054268411168, 5074.8525235191937, 5568.9807761289339]
dnm2_jasp_api=[24795.976558823517, 39178.167389313014, 47499.436276315777, 75285.597129870104]
dnm2_jasp_api_std=[23511.212892866966, 120131.78837199285, 44537.309984401523, 100469.99352790201]



# data to plot

A = cltr_dmso_api
B = dnm2_dmso_api
C = cltr_jasp_api
D = dnm2_jasp_api
n_groups = len(A) 
    
# create plot
fig, ax = plt.subplots(dpi=300)
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8
 
rects1 = plt.bar(index-1.5*bar_width, A, bar_width,
                 alpha=opacity,
                 color='magenta',
                 label='Ctrl. Cltr')

rects2 = plt.bar(index -0.5*bar_width, B, bar_width,
                 alpha=opacity,
                 color='lime',
                 label='Ctrl. Dnm2')

rects1 = plt.bar(index+1.*bar_width, C, bar_width,
                 alpha=opacity,
                 color='darkmagenta',
                 label='JASP Cltr')

rects2 = plt.bar(index +2.*bar_width, D, bar_width,
                 alpha=opacity,
                 color='limegreen',
                 label='JASP Dnm2')



 
#plt.xlabel('Person')
plt.ylabel('intensity[AU]')
plt.title('api')
plt.xticks(index + bar_width/3, ('0s-34s', '34s-68s', '68s-102s', '102s-136s', '136s-170s', '170s-398s'))

plt.legend()
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.ylim(0,85000)
plt.tight_layout()
plt.show()
